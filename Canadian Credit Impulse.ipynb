# %%
import pandas as pd
import pandas_datareader.data as web
import numpy as np
import matplotlib.pyplot as plt
import datetime
import yfinance as yf
import seaborn as sns
import backtrader as bt
#import backtrader.avanyzers as btanalyzers
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 40, 20
# %matplotlib inline

import matplotlib.cbook as cbook
import matplotlib.dates as mdates
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Credit_Impulse.csv")

# %%
data = data.iloc[::-1]
data
# Out:
#            Date GDP (MCAD with text) (CAGDP Index)  GDP (MCAD) (CAGDP Index)  \
# 103  01/31/2013                              1.73M                     1.730
# 102  02/28/2013                             1.735M                     1.735
# 101  03/31/2013                             1.741M                     1.741
# 100  04/30/2013                             1.744M                     1.744
# 99   05/31/2013                             1.749M                     1.749
# ..          ...                                ...                       ...
# 4    04/30/2021                             1.963M                     1.963
# 3    05/31/2021                             1.953M                     1.953
# 2    06/30/2021                             1.966M                     1.966
# 1    07/31/2021                             1.965M                     1.965
# 0    08/31/2021                             1.973M                     1.973
#
# ...

# %% [markdown]
# # Both Plots

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots(figsize=(15,7))

#mdates.MonthLocator(interval=14)
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
#ax.xaxis.set_major_locator(days)


plt.plot(data['Date'], data['Credit Impulse (% MoM)'], color='r')
plt.plot(data['Date'], data['Credit Impulse (% YoY)'], color='g')
plt.title("Canadian Credit Impulse MoM% (Red) and YoY% (Green)")
plt.xlabel('Date Range')
plt.ylabel('Credit Impulse % (Credit Issued / GDP)')

fig.autofmt_xdate()
n=6
ax.set_xticks(ax.get_xticks()[::n])



plt.axhline(0, color='k',linewidth=0.5)


plt.show()

# %% [markdown]
# # MoM Plot

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots(figsize=(15,7))

#mdates.MonthLocator(interval=14)
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
#ax.xaxis.set_major_locator(days)


plt.plot(data['Date'], data['Credit Impulse (% MoM)'], color='r')
plt.title("Canadian Credit Impulse MoM %")
plt.xlabel('Date Range')
plt.ylabel('Credit Impulse % (Credit Issued / GDP)')

fig.autofmt_xdate()
n=6
ax.set_xticks(ax.get_xticks()[::n])



plt.axhline(0, color='k',linewidth=0.5)


plt.show()

# %% [markdown]
# # YoY Plot

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots(figsize=(15,7))

#mdates.MonthLocator(interval=14)
#ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
#ax.xaxis.set_major_locator(days)



plt.plot(data['Date'], data['Credit Impulse (% YoY)'], color='g')
plt.title("Canadian Credit Impulse YoY %")
plt.xlabel('Date Range')
plt.ylabel('Credit Impulse % (Credit Issued / GDP)')

fig.autofmt_xdate()
n=6
ax.set_xticks(ax.get_xticks()[::n])



plt.axhline(0, color='k',linewidth=0.5)


plt.show()
